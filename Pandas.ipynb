# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
     'id': list(range(1001, 1007)),
     'date': pd.date_range(start='20130102', periods=6),
     'location':['China-Beijing ', 'China-SH', 'China-guangzhou ', 'China-Shenzhen', 'China-shanghai', 'China-BEIJING'],
     'age': [23,44,54,32,34,32],
     'category':['100-A', '100-B', '110-A', '110-C', '210-A', '130-F'],
     'price':[1200, np.nan, 2133, 5433, np.nan, 4432],
     
})

df
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     NaN
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06    China-shanghai   34    210-A     NaN
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %% [markdown]
# ### Check datafram

# %%
df.columns
# Out:
# Index(['id', 'date', 'location', 'age', 'category', 'price'], dtype='object')

# %%
df.columns.values
# Out:
# array(['id', 'date', 'location', 'age', 'category', 'price'], dtype=object)

# %%
df.shape
# Out:
# (6, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# location    6 non-null object
# age         6 non-null int64
# category    6 non-null object
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes

# %%
df.dtypes
# Out:
# id                   int64
# date        datetime64[ns]
# location            object
# age                  int64
# category            object
# price              float64
# dtype: object

# %%
df.isnull()
# Out:
#       id   date  location    age  category  price
# 0  False  False     False  False     False  False
# 1  False  False     False  False     False   True
# 2  False  False     False  False     False  False
# 3  False  False     False  False     False  False
# 4  False  False     False  False     False   True
# 5  False  False     False  False     False  False

# %%
df.isnull().sum()
# Out:
# id          0
# date        0
# location    0
# age         0
# category    0
# price       2
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['China-Beijing ', 'China-SH', 'China-guangzhou ', 'China-Shenzhen',
#        'China-shanghai', 'China-BEIJING'], dtype=object)

# %%
df['age'].values
# Out:
# array([23, 44, 54, 32, 34, 32])

# %%
df['age']
# Out:
# 0    23
# 1    44
# 2    54
# 3    32
# 4    34
# 5    32
# Name: age, dtype: int64

# %%
df['age'][3]
# Out:
# 32

# %%
df['age'].values[3]
# Out:
# 32

# %%
df.head(3)
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     NaN
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0

# %% [markdown]
# ### Dataframe cleaning

# %%
df.dropna()
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %%
df.fillna(value=0)
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     0.0
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06    China-shanghai   34    210-A     0.0
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %%
df['price'] = df['price'].fillna(df.price.mean())

# %%
df
# Out:
#      id       date         location  age category   price
# 0  1001 2013-01-02    china-beijing   23    100-A  1200.0
# 1  1002 2013-01-03         china-sh   44    100-B  3299.5
# 2  1003 2013-01-04  china-guangzhou   54    110-A  2133.0
# 3  1004 2013-01-05   china-shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06   china-shanghai   34    210-A  3299.5
# 5  1006 2013-01-07    china-beijing   32    130-F  4432.0

# %%
df['location'] = df['location'].map(str.strip)

# %%
df['location'] = df['location'].map(str.lower)

# %%
df
# Out:
#      id       date         location  age category   price
# 0  1001 2013-01-02    china-beijing   23    100-A  1200.0
# 1  1002 2013-01-03         china-sh   44    100-B     NaN
# 2  1003 2013-01-04  china-guangzhou   54    110-A  2133.0
# 3  1004 2013-01-05   china-shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06   china-shanghai   34    210-A     NaN
# 5  1006 2013-01-07    china-beijing   32    130-F  4432.0

# %%
df['price'] = df['price'].astype('int')

# %%
df.dtypes
# Out:
# id                   int64
# date        datetime64[ns]
# location            object
# age                  int64
# category            object
# price                int64
# dtype: object

# %%
df
# Out:
#      id       date         location  age category  price
# 0  1001 2013-01-02    china-beijing   23    100-A   1200
# 1  1002 2013-01-03         china-sh   44    100-B   3299
# 2  1003 2013-01-04  china-guangzhou   54    110-A   2133
# 3  1004 2013-01-05   china-shenzhen   32    110-C   5433
# 4  1005 2013-01-06   china-shanghai   34    210-A   3299
# 5  1006 2013-01-07    china-beijing   32    130-F   4432

# %%
import re
df['county'] = df['location'].apply(lambda x: re.split('\W+', x)[0])
df['city'] = df['location'].apply(lambda x: re.split('\W+', x)[1])

# %%
df
# Out:
#      id       date         location  age category  price county       city
# 0  1001 2013-01-02    china-beijing   23    100-A   1200  china    beijing
# 1  1002 2013-01-03         china-sh   44    100-B   3299  china         sh
# 2  1003 2013-01-04  china-guangzhou   54    110-A   2133  china  guangzhou
# 3  1004 2013-01-05   china-shenzhen   32    110-C   5433  china   shenzhen
# 4  1005 2013-01-06   china-shanghai   34    210-A   3299  china   shanghai
# 5  1006 2013-01-07    china-beijing   32    130-F   4432  china    beijing

# %%
df.drop(columns='location', inplace=True)

# %%
df
# Out:
#      id       date  age category  price county       city
# 0  1001 2013-01-02   23    100-A   1200  china    beijing
# 1  1002 2013-01-03   44    100-B   3299  china         sh
# 2  1003 2013-01-04   54    110-A   2133  china  guangzhou
# 3  1004 2013-01-05   32    110-C   5433  china   shenzhen
# 4  1005 2013-01-06   34    210-A   3299  china   shanghai
# 5  1006 2013-01-07   32    130-F   4432  china    beijing

# %%
df.rename(columns={'category':'category-size'}, inplace=True)
df
# Out:
#      id       date  age category-size  price county       city
# 0  1001 2013-01-02   23         100-A   1200  china    beijing
# 1  1002 2013-01-03   44         100-B   3299  china         sh
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai
# 5  1006 2013-01-07   32         130-F   4432  china    beijing

# %%
df['city'].drop_duplicates(keep='last')
# Out:
# 1           sh
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# 5      beijing
# Name: city, dtype: object

# %%
df['city'].replace('sh', 'shanghai', inplace=True)

# %%
df
# Out:
#      id       date  age category-size  price county       city
# 0  1001 2013-01-02   23         100-A   1200  china    beijing
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai
# 5  1006 2013-01-07   32         130-F   4432  china    beijing

# %%
df1 = pd.DataFrame({
    'id':list(range(1001,1009)),
    'gender':['male','female','male','female','male','female','male','female'],
    'pay':['Y','N','Y','Y','N','Y','N','Y'],
    'm-point':[10,12,20,40,40,40,30,20]
    })
df1
# Out:
#      id  gender pay  m-point
# 0  1001    male   Y       10
# 1  1002  female   N       12
# 2  1003    male   Y       20
# 3  1004  female   Y       40
# 4  1005    male   N       40
# 5  1006  female   Y       40
# 6  1007    male   N       30
# 7  1008  female   Y       20

# %%
df_inner = pd.merge(df, df1, how='inner', on='id')

# %%
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point
# 0       10
# 1       12
# 2       20
# 3       40
# 4       40
# 5       40

# %%
df_inner.set_index('id')
# Out:
#            date  age category-size  price county       city  gender pay  \
# id
# 1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#       m-point
# id
# 1001       10
# 1002       12
# 1003       20
# 1004       40
# 1005       40
# 1006       40

# %%
df_inner.sort_values(by=['age'])# replace=True
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
#
#    m-point
# 0       10
# 3       40
# 5       40
# 4       40
# 1       12
# 2       20

# %%
df_inner.sort_index()
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point
# 0       10
# 1       12
# 2       20
# 3       40
# 4       40
# 5       40

# %%
df_inner['group'] = np.where(df_inner['price']>3000, 'high', 'low')
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point group
# 0       10   low
# 1       12  high
# 2       20   low
# 3       40  high
# 4       40  high
# 5       40  high

# %%
df_inner['group_1'] = df_inner.price.apply(lambda x: 'high' if x>3000 else 'low')
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point group group_1
# 0       10   low     low
# 1       12  high    high
# 2       20   low     low
# 3       40  high    high
# 4       40  high    high
# 5       40  high    high

# %%
df_inner.loc[(df_inner.city=='beijing') & (df_inner.price>4000), 'sign'] = 1

# %%
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point group group_1  sign
# 0       10   low     low   NaN
# 1       12  high    high   NaN
# 2       20   low     low   NaN
# 3       40  high    high   NaN
# 4       40  high    high   NaN
# 5       40  high    high   1.0

# %%
df_inner.loc[df_inner.price>3000, 'group_2'] = 'high'
df_inner.loc[df_inner.price<=3000, 'group_2'] = 'low'

# %%
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point group group_1  sign group_2
# 0       10   low     low   NaN     low
# 1       12  high    high   NaN    high
# 2       20   low     low   NaN     low
# 3       40  high    high   NaN    high
# 4       40  high    high   NaN    high
# 5       40  high    high   1.0    high

# %%
df_inner['category_1'] = df_inner['category-size'].apply(lambda x:re.split('\W+', x)[0])
df_inner['size'] = df_inner['category-size'].apply(lambda x:re.split('\W+', x)[1])
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
#
#    m-point group group_1  sign group_2 category_1 size
# 0       10   low     low   NaN     low        100    A
# 1       12  high    high   NaN    high        100    B
# 2       20   low     low   NaN     low        110    A
# 3       40  high    high   NaN    high        110    C
# 4       40  high    high   NaN    high        210    A
# 5       40  high    high   1.0    high        130    F

# %%
df_inner.sort_values(by='age', inplace=True)
df_inner
# Out:
#      id       date  age category-size  price county       city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china    beijing    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female   Y
# 5  1006 2013-01-07   32         130-F   4432  china    beijing  female   Y
# 4  1005 2013-01-06   34         210-A   3299  china   shanghai    male   N
# 1  1002 2013-01-03   44         100-B   3299  china   shanghai  female   N
# 2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male   Y
#
#    m-point group group_1  sign group_2 category_1 size
# 0       10   low     low   NaN     low        100    A
# 3       40  high    high   NaN    high        110    C
# 5       40  high    high   1.0    high        130    F
# 4       40  high    high   NaN    high        210    A
# 1       12  high    high   NaN    high        100    B
# 2       20   low     low   NaN     low        110    A

# %%
df_inner.loc[0:5]
# Out:
#      id       date  age category-size  price county      city  gender pay  \
# 0  1001 2013-01-02   23         100-A   1200  china   beijing    male   Y
# 3  1004 2013-01-05   32         110-C   5433  china  shenzhen  female   Y
# 5  1006 2013-01-07   32         130-F   4432  china   beijing  female   Y
#
#    m-point group group_1  sign group_2 category_1 size
# 0       10   low     low   NaN     low        100    A
# 3       40  high    high   NaN    high        110    C
# 5       40  high    high   1.0    high        130    F

# %%
#reset_index: generate new sequencial index, and the previous index label become a column 'index'
df_inner.reset_index()
# Out:
#    index    id       date  age category-size  price county       city  gender  \
# 0      0  1001 2013-01-02   23         100-A   1200  china    beijing    male
# 1      3  1004 2013-01-05   32         110-C   5433  china   shenzhen  female
# 2      5  1006 2013-01-07   32         130-F   4432  china    beijing  female
# 3      4  1005 2013-01-06   34         210-A   3299  china   shanghai    male
# 4      1  1002 2013-01-03   44         100-B   3299  china   shanghai  female
# 5      2  1003 2013-01-04   54         110-A   2133  china  guangzhou    male
#
#   pay  m-point group group_1  sign group_2 category_1 size
# 0   Y       10   low     low   NaN     low        100    A
# 1   Y       40  high    high   NaN    high        110    C
# 2   Y       40  high    high   1.0    high        130    F
# 3   N       40  high    high   NaN    high        210    A
# 4   N       12  high    high   NaN    high        100    B
# 5   Y       20   low     low   NaN     low        110    A

# %%
df_inner.set_index('date', inplace=True)

# %%
df_inner
# Out:
#               id  age category-size  price county       city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china    beijing    male   Y
# 2013-01-05  1004   32         110-C   5433  china   shenzhen  female   Y
# 2013-01-07  1006   32         130-F   4432  china    beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china   shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china   shanghai  female   N
# 2013-01-04  1003   54         110-A   2133  china  guangzhou    male   Y
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-05       40  high    high   NaN    high        110    C
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B
# 2013-01-04       20   low     low   NaN     low        110    A

# %%
df_inner.iloc[:3, :2]
# Out:
#               id  age
# date
# 2013-01-02  1001   23
# 2013-01-05  1004   32
# 2013-01-07  1006   32

# %%
df_inner.iloc[[0,2,5], [3,6]]
# Out:
#             price  gender
# date
# 2013-01-02   1200    male
# 2013-01-07   4432  female
# 2013-01-04   2133    male

# %%
#iloc: extract by position, only take integer
#loc: extract by label or index
#iX: combination of iloc and loc, ix is deprecated in python 3

# %%
df_inner['city'].isin(['beijing'])
# Out:
# date
# 2013-01-02     True
# 2013-01-05    False
# 2013-01-07     True
# 2013-01-06    False
# 2013-01-03    False
# 2013-01-04    False
# Name: city, dtype: bool

# %%
df_inner.query("city=='beijing' or city=='shanghai'")
# Out:
#               id  age category-size  price county      city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china   beijing    male   Y
# 2013-01-07  1006   32         130-F   4432  china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china  shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
df_inner.query("city==['beijing', 'shanghai']")
# Out:
#               id  age category-size  price county      city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china   beijing    male   Y
# 2013-01-07  1006   32         130-F   4432  china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china  shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
df_inner.query("city==['beijing', 'shanghai']").price.sum
# Out:
# <bound method Series.sum of date
# 2013-01-02    1200
# 2013-01-07    4432
# 2013-01-06    3299
# 2013-01-03    3299
# Name: price, dtype: int64>

# %%
df_inner.query("city==['beijing', 'shanghai']").price.sum()
# Out:
# 12230

# %%
df_inner[(df_inner.city=='beijing')|(df_inner.city=='shanghai')]
# Out:
#               id  age category-size  price county      city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china   beijing    male   Y
# 2013-01-07  1006   32         130-F   4432  china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china  shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
df_inner[df_inner.city.isin(['beijing','shanghai'])]
# Out:
#               id  age category-size  price county      city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china   beijing    male   Y
# 2013-01-07  1006   32         130-F   4432  china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china  shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
df_inner.loc[(df_inner.city=='beijing')|(df_inner.city=='shanghai')]
# Out:
#               id  age category-size  price county      city  gender pay  \
# date
# 2013-01-02  1001   23         100-A   1200  china   beijing    male   Y
# 2013-01-07  1006   32         130-F   4432  china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299  china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299  china  shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-02       10   low     low   NaN     low        100    A
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-06       40  high    high   NaN    high        210    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
# or:|, and:&
df_inner.loc[(df_inner.age>25)|(df_inner.city=='beijing'), ['id','city','age','category','gender']]
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#               id       city  age  category  gender
# date
# 2013-01-02  1001    beijing   23       NaN    male
# 2013-01-05  1004   shenzhen   32       NaN  female
# 2013-01-07  1006    beijing   32       NaN  female
# 2013-01-06  1005   shanghai   34       NaN    male
# 2013-01-03  1002   shanghai   44       NaN  female
# 2013-01-04  1003  guangzhou   54       NaN    male

# %%
df_inner.query("city!='beijing'")[['id','city','age','category-size','gender']]
# Out:
#               id       city  age category-size  gender
# date
# 2013-01-05  1004   shenzhen   32         110-C  female
# 2013-01-06  1005   shanghai   34         210-A    male
# 2013-01-03  1002   shanghai   44         100-B  female
# 2013-01-04  1003  guangzhou   54         110-A    male

# %%
df_inner.loc[(df_inner['city']!='beijing'), ['id','city','age','category-size','gender']]
# Out:
#               id       city  age category-size  gender
# date
# 2013-01-05  1004   shenzhen   32         110-C  female
# 2013-01-06  1005   shanghai   34         210-A    male
# 2013-01-03  1002   shanghai   44         100-B  female
# 2013-01-04  1003  guangzhou   54         110-A    male

# %%
df_inner.loc[(df_inner['city']!='beijing'), ['id','city','age','category-size','gender']].sort_values(by='id')
# Out:
#               id       city  age category-size  gender
# date
# 2013-01-03  1002   shanghai   44         100-B  female
# 2013-01-04  1003  guangzhou   54         110-A    male
# 2013-01-05  1004   shenzhen   32         110-C  female
# 2013-01-06  1005   shanghai   34         210-A    male

# %%
df_inner[['id','city']]
# Out:
#               id       city
# date
# 2013-01-02  1001    beijing
# 2013-01-05  1004   shenzhen
# 2013-01-07  1006    beijing
# 2013-01-06  1005   shanghai
# 2013-01-03  1002   shanghai
# 2013-01-04  1003  guangzhou

# %%
df_inner.groupby('city').size()
# Out:
# city
# beijing      2
# guangzhou    1
# shanghai     2
# shenzhen     1
# dtype: int64

# %%
df_inner.groupby(['city','gender']).size()
# Out:
# city       gender
# beijing    female    1
#            male      1
# guangzhou  male      1
# shanghai   female    1
#            male      1
# shenzhen   female    1
# dtype: int64

# %%
df_inner.groupby('city').count()
# Out:
#            id  age  category-size  price  county  gender  pay  m-point  group  \
# city
# beijing     2    2              2      2       2       2    2        2      2
# guangzhou   1    1              1      1       1       1    1        1      1
# shanghai    2    2              2      2       2       2    2        2      2
# shenzhen    1    1              1      1       1       1    1        1      1
#
#            group_1  sign  group_2  category_1  size
# city
# beijing          2     1        2           2     2
# guangzhou        1     0        1           1     1
# shanghai         2     0        2           2     2
# shenzhen         1     0        1           1     1

# %%
df_inner.groupby(['city','size'])['id'].count()
# Out:
# city       size
# beijing    A       1
#            F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# Name: id, dtype: int64

# %%
df_inner.groupby(['city','size'])['id'].size()
# Out:
# city       size
# beijing    A       1
#            F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# Name: id, dtype: int64

# %%
df_inner.groupby('city')['price'].aggregate([len, np.sum, np.mean])
# Out:
#            len   sum  mean
# city
# beijing      2  5632  2816
# guangzhou    1  2133  2133
# shanghai     2  6598  3299
# shenzhen     1  5433  5433

# %%
df_inner.groupby('city')['price'].sum()
# Out:
# city
# beijing      5632
# guangzhou    2133
# shanghai     6598
# shenzhen     5433
# Name: price, dtype: int64

# %%
df_inner.sample(3)
# Out:
#               id  age category-size  price county       city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432  china    beijing  female   Y
# 2013-01-05  1004   32         110-C   5433  china   shenzhen  female   Y
# 2013-01-04  1003   54         110-A   2133  china  guangzhou    male   Y
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-07       40  high    high   1.0    high        130    F
# 2013-01-05       40  high    high   NaN    high        110    C
# 2013-01-04       20   low     low   NaN     low        110    A

# %%
df_inner.sample?

# %%
weights = [0,0,0,0.01,0.49,0.5]
df_inner.sample(n=3, weights=weights)
# Out:
#               id  age category-size  price county       city  gender pay  \
# date
# 2013-01-04  1003   54         110-A   2133  china  guangzhou    male   Y
# 2013-01-03  1002   44         100-B   3299  china   shanghai  female   N
# 2013-01-06  1005   34         210-A   3299  china   shanghai    male   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-04       20   low     low   NaN     low        110    A
# 2013-01-03       12  high    high   NaN    high        100    B
# 2013-01-06       40  high    high   NaN    high        210    A

# %%
weights = [0,0,0,0.01,0.49,0.5]
df_inner.sample(n=3, weights=weights, replace=True)
# Out:
#               id  age category-size  price county       city  gender pay  \
# date
# 2013-01-03  1002   44         100-B   3299  china   shanghai  female   N
# 2013-01-04  1003   54         110-A   2133  china  guangzhou    male   Y
# 2013-01-03  1002   44         100-B   3299  china   shanghai  female   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-03       12  high    high   NaN    high        100    B
# 2013-01-04       20   low     low   NaN     low        110    A
# 2013-01-03       12  high    high   NaN    high        100    B

# %%
#replace=True: 又放回的取样，会有重复的sample
weights = [0,0,0,0.01,0.49,0.5]
df_inner.sample(n=3, weights=weights, replace=False)
# Out:
#               id  age category-size  price county       city  gender pay  \
# date
# 2013-01-04  1003   54         110-A   2133  china  guangzhou    male   Y
# 2013-01-03  1002   44         100-B   3299  china   shanghai  female   N
# 2013-01-06  1005   34         210-A   3299  china   shanghai    male   N
#
#             m-point group group_1  sign group_2 category_1 size
# date
# 2013-01-04       20   low     low   NaN     low        110    A
# 2013-01-03       12  high    high   NaN    high        100    B
# 2013-01-06       40  high    high   NaN    high        210    A

# %%
df_inner.describe().T.round(2)
# Out:
#          count     mean      std     min      25%     50%      75%     max
# id         6.0  1003.50     1.87  1001.0  1002.25  1003.5  1004.75  1006.0
# age        6.0    36.50    10.88    23.0    32.00    33.0    41.50    54.0
# price      6.0  3299.33  1523.35  1200.0  2424.50  3299.0  4148.75  5433.0
# m-point    6.0    27.00    14.63    10.0    14.00    30.0    40.00    40.0
# sign       1.0     1.00      NaN     1.0     1.00     1.0     1.00     1.0

# %%
df_inner.corr()
# Out:
#                id       age     price   m-point  sign
# id       1.000000 -0.034401  0.682824  0.928096   NaN
# age     -0.034401  1.000000 -0.081720 -0.194833   NaN
# price    0.682824 -0.081720  1.000000  0.774666   NaN
# m-point  0.928096 -0.194833  0.774666  1.000000   NaN
# sign          NaN       NaN       NaN       NaN   NaN

# %%
df_inner.to_excel('df_inner.xlsx', sheet_name='Sheet_1')

# %%
df_inner.to_csv('df_inner.csv')
