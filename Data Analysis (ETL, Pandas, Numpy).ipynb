# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Create DataFrame

# %%
df = pd.DataFrame({
    'id': list(range(1001, 1007)),
    'date': pd.date_range(start='20130102', periods=6),
    'location': ['China-Beijing ', 'China-SH', 'China-guangzhou ', 'China-Shenzhen', 'China-shanghai', 'China-BEIJING'],
    'age': [23,44,54,32,34,32],
    'category': ['100-A', '100-B', '110-A', '110-C', '210-A', '130-F'],
    'price': [1200, np.nan, 2133, 5433, np.nan, 4432]  
})

df
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     NaN
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06    China-shanghai   34    210-A     NaN
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# location    6 non-null object
# age         6 non-null int64
# category    6 non-null object
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes

# %%
df.columns
# Out:
# Index(['id', 'date', 'location', 'age', 'category', 'price'], dtype='object')

# %%
df.columns.values
# Out:
# array(['id', 'date', 'location', 'age', 'category', 'price'], dtype=object)

# %%
df.shape
# Out:
# (6, 6)

# %%
df.dtypes
# Out:
# id                   int64
# date        datetime64[ns]
# location            object
# age                  int64
# category            object
# price              float64
# dtype: object

# %%
df.isnull()
# Out:
#       id   date  location    age  category  price
# 0  False  False     False  False     False  False
# 1  False  False     False  False     False   True
# 2  False  False     False  False     False  False
# 3  False  False     False  False     False  False
# 4  False  False     False  False     False   True
# 5  False  False     False  False     False  False

# %%
df.isnull().sum()
# Out:
# id          0
# date        0
# location    0
# age         0
# category    0
# price       2
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['China-Beijing ', 'China-SH', 'China-guangzhou ', 'China-Shenzhen',
#        'China-shanghai', 'China-BEIJING'], dtype=object)

# %%
df.age
# Out:
# 0    23
# 1    44
# 2    54
# 3    32
# 4    34
# 5    32
# Name: age, dtype: int64

# %%
df.head(3)
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     NaN
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0

# %%
df.age[3]
# Out:
# 32

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Drop & Imputate missing values

# %%
df.dropna()
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %%
df.fillna(0)
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B     0.0
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06    China-shanghai   34    210-A     0.0
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %%
df['price'] = df['price'].fillna(df.price.mean())
df
# Out:
#      id       date          location  age category   price
# 0  1001 2013-01-02    China-Beijing    23    100-A  1200.0
# 1  1002 2013-01-03          China-SH   44    100-B  3299.5
# 2  1003 2013-01-04  China-guangzhou    54    110-A  2133.0
# 3  1004 2013-01-05    China-Shenzhen   32    110-C  5433.0
# 4  1005 2013-01-06    China-shanghai   34    210-A  3299.5
# 5  1006 2013-01-07     China-BEIJING   32    130-F  4432.0

# %% [markdown]
# ### Unify Column format

# %%
df['location'].values
# need to remove space
# Out:
# array(['China-Beijing ', 'China-SH', 'China-guangzhou ', 'China-Shenzhen',
#        'China-shanghai', 'China-BEIJING'], dtype=object)

# %%
df['location'] = df['location'].map(str.strip).map(str.lower)

# %% [markdown]
# ### Split Columns

# %%
df['country'] = df['location'].apply(lambda x: re.split('\W+', x)[0])
df['city'] = df['location'].apply(lambda x: re.split('\W+', x)[1])
df
# Out:
#      id       date         location  age category   price country       city
# 0  1001 2013-01-02    china-beijing   23    100-A  1200.0   china    beijing
# 1  1002 2013-01-03         china-sh   44    100-B  3299.5   china         sh
# 2  1003 2013-01-04  china-guangzhou   54    110-A  2133.0   china  guangzhou
# 3  1004 2013-01-05   china-shenzhen   32    110-C  5433.0   china   shenzhen
# 4  1005 2013-01-06   china-shanghai   34    210-A  3299.5   china   shanghai
# 5  1006 2013-01-07    china-beijing   32    130-F  4432.0   china    beijing

# %% [markdown]
# ### Change Data type

# %%
df['price'] = df['price'].astype('int32')

# %% [markdown]
# ### Drop columns, rows

# %%
# drop columns
df.drop(columns='location', inplace=True)

# %%
df
# Out:
#      id       date  age category  price country       city
# 0  1001 2013-01-02   23    100-A   1200   china    beijing
# 1  1002 2013-01-03   44    100-B   3299   china         sh
# 2  1003 2013-01-04   54    110-A   2133   china  guangzhou
# 3  1004 2013-01-05   32    110-C   5433   china   shenzhen
# 4  1005 2013-01-06   34    210-A   3299   china   shanghai
# 5  1006 2013-01-07   32    130-F   4432   china    beijing

# %%
# drop rows
df.drop([0,3])
# Out:
#      id       date  age category  price country       city
# 1  1002 2013-01-03   44    100-B   3299   china         sh
# 2  1003 2013-01-04   54    110-A   2133   china  guangzhou
# 4  1005 2013-01-06   34    210-A   3299   china   shanghai
# 5  1006 2013-01-07   32    130-F   4432   china    beijing

# %%
# drop rows where price<3000
df.drop(df[df.price<3000].index)
# Out:
#      id       date  age category  price country      city
# 1  1002 2013-01-03   44    100-B   3299   china        sh
# 3  1004 2013-01-05   32    110-C   5433   china  shenzhen
# 4  1005 2013-01-06   34    210-A   3299   china  shanghai
# 5  1006 2013-01-07   32    130-F   4432   china   beijing

# %% [markdown]
# ### Rename Columns

# %%
df.rename(columns={'category':'category-size'}, inplace=True)
df
# Out:
#      id       date  age category-size  price country       city
# 0  1001 2013-01-02   23         100-A   1200   china    beijing
# 1  1002 2013-01-03   44         100-B   3299   china         sh
# 2  1003 2013-01-04   54         110-A   2133   china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433   china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299   china   shanghai
# 5  1006 2013-01-07   32         130-F   4432   china    beijing

# %% [markdown]
# ### Drop duplicate rows

# %%
df.drop_duplicates(subset=['city'], keep='last', inplace=True)
df
# Out:
#      id       date  age category-size  price country       city
# 1  1002 2013-01-03   44         100-B   3299   china         sh
# 2  1003 2013-01-04   54         110-A   2133   china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433   china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299   china   shanghai
# 5  1006 2013-01-07   32         130-F   4432   china    beijing

# %% [markdown]
# ### Update values

# %%
df['city'].replace('sh', 'shanghai', inplace=True)
df
# Out:
#      id       date  age category-size  price country       city
# 1  1002 2013-01-03   44         100-B   3299   china   shanghai
# 2  1003 2013-01-04   54         110-A   2133   china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433   china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299   china   shanghai
# 5  1006 2013-01-07   32         130-F   4432   china    beijing

# %% [markdown]
# ### Merge df, df1

# %%
df1 = pd.DataFrame({
    'id':list(range(1001,1009)),
    'gender':['male','female','male','female','male','female','male','female'],
    'pay':['Y','N','Y','Y','N','Y','N','Y'],
    'm-point':[10,12,20,40,40,40,30,20]
})
df1
# Out:
#      id  gender pay  m-point
# 0  1001    male   Y       10
# 1  1002  female   N       12
# 2  1003    male   Y       20
# 3  1004  female   Y       40
# 4  1005    male   N       40
# 5  1006  female   Y       40
# 6  1007    male   N       30
# 7  1008  female   Y       20

# %%
df_inner = pd.merge(df, df1, how='inner', on='id')
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point
# 0       12
# 1       20
# 2       40
# 3       40
# 4       40

# %% [markdown]
# ### Set Index

# %%
df_inner.set_index('id')
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point
# 0       12
# 1       20
# 2       40
# 3       40
# 4       40

# %% [markdown]
# ### Sort

# %%
df_inner.sort_values(by='age')
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
#
#    m-point
# 2       40
# 4       40
# 3       40
# 0       12
# 1       20

# %%
df
# Out:
#      id       date  age category-size  price country       city
# 1  1002 2013-01-03   44         100-B   3299   china   shanghai
# 2  1003 2013-01-04   54         110-A   2133   china  guangzhou
# 3  1004 2013-01-05   32         110-C   5433   china   shenzhen
# 4  1005 2013-01-06   34         210-A   3299   china   shanghai
# 5  1006 2013-01-07   32         130-F   4432   china    beijing

# %% [markdown]
# ### Add New Columns Based on Conditions

# %%
# way 1
df_inner['group'] = np.where(df_inner.price>3000, 'high', 'low')
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point group
# 0       12  high
# 1       20   low
# 2       40  high
# 3       40  high
# 4       40  high

# %%
# way 2
df_inner['group_1'] = df_inner.price.apply(lambda x: 'high' if x>3000 else 'low')
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point group group_1
# 0       12  high    high
# 1       20   low     low
# 2       40  high    high
# 3       40  high    high
# 4       40  high    high

# %%
# way 3
df_inner.loc[df_inner.price>3000, 'group_2'] = 'high'
df_inner.loc[df_inner.price<=3000, 'group_2'] = 'low'
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point group group_1 group_2
# 0       12  high    high    high
# 1       20   low     low     low
# 2       40  high    high    high
# 3       40  high    high    high
# 4       40  high    high    high

# %%
df_inner['category'] = df_inner['category-size'].apply(lambda x: re.split('\W+', x)[0])
df_inner['size'] = df_inner['category-size'].apply(lambda x: re.split('\W+', x)[1])
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
#
#    m-point group group_1 group_2 category size
# 0       12  high    high    high      100    B
# 1       20   low     low     low      110    A
# 2       40  high    high    high      110    C
# 3       40  high    high    high      210    A
# 4       40  high    high    high      130    F

# %%
df_inner.sort_values(by='age', inplace=True)
df_inner
# Out:
#      id       date  age category-size  price country       city  gender pay  \
# 2  1004 2013-01-05   32         110-C   5433   china   shenzhen  female   Y
# 4  1006 2013-01-07   32         130-F   4432   china    beijing  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china   shanghai    male   N
# 0  1002 2013-01-03   44         100-B   3299   china   shanghai  female   N
# 1  1003 2013-01-04   54         110-A   2133   china  guangzhou    male   Y
#
#    m-point group group_1 group_2 category size
# 2       40  high    high    high      110    C
# 4       40  high    high    high      130    F
# 3       40  high    high    high      210    A
# 0       12  high    high    high      100    B
# 1       20   low     low     low      110    A

# %%
df_inner.loc[2:3]
# Out:
#      id       date  age category-size  price country      city  gender pay  \
# 2  1004 2013-01-05   32         110-C   5433   china  shenzhen  female   Y
# 4  1006 2013-01-07   32         130-F   4432   china   beijing  female   Y
# 3  1005 2013-01-06   34         210-A   3299   china  shanghai    male   N
#
#    m-point group group_1 group_2 category size
# 2       40  high    high    high      110    C
# 4       40  high    high    high      130    F
# 3       40  high    high    high      210    A

# %%
df_inner.reset_index()
#reset_index: generate new sequencial index, and the previous index label become a column 'index'
# Out:
#    index    id       date  age category-size  price country       city  \
# 0      2  1004 2013-01-05   32         110-C   5433   china   shenzhen
# 1      4  1006 2013-01-07   32         130-F   4432   china    beijing
# 2      3  1005 2013-01-06   34         210-A   3299   china   shanghai
# 3      0  1002 2013-01-03   44         100-B   3299   china   shanghai
# 4      1  1003 2013-01-04   54         110-A   2133   china  guangzhou
#
#    gender pay  m-point group group_1 group_2 category size
# 0  female   Y       40  high    high    high      110    C
# 1  female   Y       40  high    high    high      130    F
# 2    male   N       40  high    high    high      210    A
# 3  female   N       12  high    high    high      100    B
# 4    male   Y       20   low     low     low      110    A

# %%
df_inner.set_index('date', inplace=True)

# %%
df_inner
# Out:
#               id  age category-size  price country       city  gender pay  \
# date
# 2013-01-05  1004   32         110-C   5433   china   shenzhen  female   Y
# 2013-01-07  1006   32         130-F   4432   china    beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china   shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china   shanghai  female   N
# 2013-01-04  1003   54         110-A   2133   china  guangzhou    male   Y
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-05       40  high    high    high      110    C
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B
# 2013-01-04       20   low     low     low      110    A

# %%
df_inner.loc['first_hand']='yes'
df_inner
# Out:
#                        id  age category-size price country       city  gender  \
# date
# 2013-01-05 00:00:00  1004   32         110-C  5433   china   shenzhen  female
# 2013-01-07 00:00:00  1006   32         130-F  4432   china    beijing  female
# 2013-01-06 00:00:00  1005   34         210-A  3299   china   shanghai    male
# 2013-01-03 00:00:00  1002   44         100-B  3299   china   shanghai  female
# 2013-01-04 00:00:00  1003   54         110-A  2133   china  guangzhou    male
# first_hand            yes  yes           yes   yes     yes        yes     yes
#
#                      pay m-point group group_1 group_2 category size
# date
# 2013-01-05 00:00:00    Y      40  high    high    high      110    C
# 2013-01-07 00:00:00    Y      40  high    high    high      130    F
# 2013-01-06 00:00:00    N      40  high    high    high      210    A
# 2013-01-03 00:00:00    N      12  high    high    high      100    B
# 2013-01-04 00:00:00    Y      20   low     low     low      110    A
# first_hand           yes     yes   yes     yes     yes      yes  yes

# %%
df_inner.drop('first_hand', inplace=True)

# %%
df_inner
# Out:
#                        id age category-size price country       city  gender  \
# date
# 2013-01-05 00:00:00  1004  32         110-C  5433   china   shenzhen  female
# 2013-01-07 00:00:00  1006  32         130-F  4432   china    beijing  female
# 2013-01-06 00:00:00  1005  34         210-A  3299   china   shanghai    male
# 2013-01-03 00:00:00  1002  44         100-B  3299   china   shanghai  female
# 2013-01-04 00:00:00  1003  54         110-A  2133   china  guangzhou    male
#
#                     pay m-point group group_1 group_2 category size
# date
# 2013-01-05 00:00:00   Y      40  high    high    high      110    C
# 2013-01-07 00:00:00   Y      40  high    high    high      130    F
# 2013-01-06 00:00:00   N      40  high    high    high      210    A
# 2013-01-03 00:00:00   N      12  high    high    high      100    B
# 2013-01-04 00:00:00   Y      20   low     low     low      110    A

# %%
df_inner.loc[:, 'first_hand']='yes'
df_inner
# Out:
#                        id age category-size price country       city  gender  \
# date
# 2013-01-05 00:00:00  1004  32         110-C  5433   china   shenzhen  female
# 2013-01-07 00:00:00  1006  32         130-F  4432   china    beijing  female
# 2013-01-06 00:00:00  1005  34         210-A  3299   china   shanghai    male
# 2013-01-03 00:00:00  1002  44         100-B  3299   china   shanghai  female
# 2013-01-04 00:00:00  1003  54         110-A  2133   china  guangzhou    male
#
#                     pay m-point group group_1 group_2 category size first_hand
# date
# 2013-01-05 00:00:00   Y      40  high    high    high      110    C        yes
# 2013-01-07 00:00:00   Y      40  high    high    high      130    F        yes
# 2013-01-06 00:00:00   N      40  high    high    high      210    A        yes
# 2013-01-03 00:00:00   N      12  high    high    high      100    B        yes
# 2013-01-04 00:00:00   Y      20   low     low     low      110    A        yes

# %% [markdown]
# ### Access Data

# %%
df_inner.iloc[:3,:2]
# Out:
#               id  age
# date
# 2013-01-05  1004   32
# 2013-01-07  1006   32
# 2013-01-06  1005   34

# %%
df_inner.iloc[[0,2,4], [3,6]]
# Out:
#             price  gender
# date
# 2013-01-05   5433  female
# 2013-01-06   3299    male
# 2013-01-04   2133    male

# %%
df_inner['city'].isin(['beijing'])
# Out:
# date
# 2013-01-05    False
# 2013-01-07     True
# 2013-01-06    False
# 2013-01-03    False
# 2013-01-04    False
# Name: city, dtype: bool

# %% [markdown]
# ### Filtering

# %%
df_inner.loc[(df_inner['city']=='beijing')|(df_inner['city']=='shanghai')]
# Out:
#               id  age category-size  price country      city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432   china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china  shanghai  female   N
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B

# %%
df_inner.query("city=='beijing' or city=='shanghai'")
# Out:
#               id  age category-size  price country      city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432   china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china  shanghai  female   N
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B

# %%
df_inner[(df_inner['city']=='beijing')|(df_inner['city']=='shanghai')]
# Out:
#               id  age category-size  price country      city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432   china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china  shanghai  female   N
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B

# %%
df_inner.loc[df_inner.city.isin(['beijing','shanghai'])]
# Out:
#               id  age category-size  price country      city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432   china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china  shanghai  female   N
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B

# %%
df_inner.query("city==['beijing','shanghai']")
# Out:
#               id  age category-size  price country      city  gender pay  \
# date
# 2013-01-07  1006   32         130-F   4432   china   beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china  shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china  shanghai  female   N
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B

# %%
df_inner[(df_inner.city=='beijing')|(df_inner.city=='shanghai')].price.sum()
# Out:
# 11030

# %%
df_inner[(df_inner.city=='beijing')|(df_inner.city=='shanghai')].price.mean()
# Out:
# 3676.6666666666665

# %%
df_inner[(df_inner.city=='beijing')|(df_inner.city=='shanghai')].price.median()
# Out:
# 3299.0

# %%
df_inner.loc[(df_inner.age>25)|(df_inner.city=='beijing'),['id','city','age','category','gender']]
# Out:
#               id       city  age category  gender
# date
# 2013-01-05  1004   shenzhen   32      110  female
# 2013-01-07  1006    beijing   32      130  female
# 2013-01-06  1005   shanghai   34      210    male
# 2013-01-03  1002   shanghai   44      100  female
# 2013-01-04  1003  guangzhou   54      110    male

# %%
df_inner.loc[(df_inner.city!='beijing'),['id','city','age','category','gender']]
# Out:
#               id       city  age category  gender
# date
# 2013-01-05  1004   shenzhen   32      110  female
# 2013-01-06  1005   shanghai   34      210    male
# 2013-01-03  1002   shanghai   44      100  female
# 2013-01-04  1003  guangzhou   54      110    male

# %%
df_inner.query("city!='beijing'")[['id','city','age','category','gender']]
# Out:
#               id       city  age category  gender
# date
# 2013-01-05  1004   shenzhen   32      110  female
# 2013-01-06  1005   shanghai   34      210    male
# 2013-01-03  1002   shanghai   44      100  female
# 2013-01-04  1003  guangzhou   54      110    male

# %%
df_inner[df_inner.city!='beijing'][['id','city','age','category','gender']]
# Out:
#               id       city  age category  gender
# date
# 2013-01-05  1004   shenzhen   32      110  female
# 2013-01-06  1005   shanghai   34      210    male
# 2013-01-03  1002   shanghai   44      100  female
# 2013-01-04  1003  guangzhou   54      110    male

# %%
df_inner.loc[(df_inner.city!='beijing'),['id','city','age','category','gender']].sort_values(by='id')
# Out:
#               id       city  age category  gender
# date
# 2013-01-03  1002   shanghai   44      100  female
# 2013-01-04  1003  guangzhou   54      110    male
# 2013-01-05  1004   shenzhen   32      110  female
# 2013-01-06  1005   shanghai   34      210    male

# %%
df_inner[['id','city']]
# Out:
#               id       city
# date
# 2013-01-05  1004   shenzhen
# 2013-01-07  1006    beijing
# 2013-01-06  1005   shanghai
# 2013-01-03  1002   shanghai
# 2013-01-04  1003  guangzhou

# %% [markdown]
# ### Groupby & Aggregation

# %%
df_inner.groupby('city').size()
# Out:
# city
# beijing      1
# guangzhou    1
# shanghai     2
# shenzhen     1
# dtype: int64

# %%
df_inner.groupby('city').count()
# Out:
#            id  age  category-size  price  country  gender  pay  m-point  \
# city
# beijing     1    1              1      1        1       1    1        1
# guangzhou   1    1              1      1        1       1    1        1
# shanghai    2    2              2      2        2       2    2        2
# shenzhen    1    1              1      1        1       1    1        1
#
#            group  group_1  group_2  category  size
# city
# beijing        1        1        1         1     1
# guangzhou      1        1        1         1     1
# shanghai       2        2        2         2     2
# shenzhen       1        1        1         1     1

# %%
df_inner.groupby('city').count()['price']
# Out:
# city
# beijing      1
# guangzhou    1
# shanghai     2
# shenzhen     1
# Name: price, dtype: int64

# %%
df_inner.groupby(['city','size']).size()
# Out:
# city       size
# beijing    F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# dtype: int64

# %%
df_inner.groupby(['city','size']).size().to_frame('count')
# Out:
#                 count
# city      size
# beijing   F         1
# guangzhou A         1
# shanghai  A         1
#           B         1
# shenzhen  C         1

# %%
df_inner.groupby(['city','size']).count()
# Out:
#                 id  age  category-size  price  country  gender  pay  m-point  \
# city      size
# beijing   F      1    1              1      1        1       1    1        1
# guangzhou A      1    1              1      1        1       1    1        1
# shanghai  A      1    1              1      1        1       1    1        1
#           B      1    1              1      1        1       1    1        1
# shenzhen  C      1    1              1      1        1       1    1        1
#
#                 group  group_1  group_2  category
# city      size
# beijing   F         1        1        1         1
# guangzhou A         1        1        1         1
# shanghai  A         1        1        1         1
#           B         1        1        1         1
# shenzhen  C         1        1        1         1

# %%
df_inner.groupby(['city','size']).count()['price']
# Out:
# city       size
# beijing    F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# Name: price, dtype: int64

# %%
df_inner.groupby(['city','size'])['price'].sum().to_frame('sum')
# Out:
#                  sum
# city      size
# beijing   F     4432
# guangzhou A     2133
# shanghai  A     3299
#           B     3299
# shenzhen  C     5433

# %%
df_inner.groupby(['city','size'])['price'].mean().to_frame('mean')
# Out:
#                 mean
# city      size
# beijing   F     4432
# guangzhou A     2133
# shanghai  A     3299
#           B     3299
# shenzhen  C     5433

# %%
df_inner.groupby(['city','size'])['price'].aggregate([len, np.mean, np.sum])
# Out:
#                 len  mean   sum
# city      size
# beijing   F       1  4432  4432
# guangzhou A       1  2133  2133
# shanghai  A       1  3299  3299
#           B       1  3299  3299
# shenzhen  C       1  5433  5433

# %%
df_inner.groupby(['city','size'])['price'].aggregate([np.mean])
# Out:
#                 mean
# city      size
# beijing   F     4432
# guangzhou A     2133
# shanghai  A     3299
#           B     3299
# shenzhen  C     5433

# %% [markdown]
# ### Pivot Table

# %%
df_inner.pivot_table(index='city', values='price', aggfunc='mean')
# Out:
#            price
# city
# beijing     4432
# guangzhou   2133
# shanghai    3299
# shenzhen    5433

# %%
df_inner.groupby('city')['price'].aggregate([np.mean])
# Out:
#            mean
# city
# beijing    4432
# guangzhou  2133
# shanghai   3299
# shenzhen   5433

# %%
df_pivot = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df_pivot
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df_pivot.pivot_table(index=['A','B'], columns=['C'], aggfunc='sum')
# Out:
#             D           E
# C       large small large small
# A   B
# bar one   4.0   5.0   6.0   8.0
#     two   7.0   6.0   9.0   9.0
# foo one   4.0   1.0   9.0   2.0
#     two   NaN   6.0   NaN  11.0

# %%
df_pivot.pivot_table(index=['A','B'], columns=['C'], aggfunc=np.sum)
# Out:
#             D           E
# C       large small large small
# A   B
# bar one   4.0   5.0   6.0   8.0
#     two   7.0   6.0   9.0   9.0
# foo one   4.0   1.0   9.0   2.0
#     two   NaN   6.0   NaN  11.0

# %%
df_pivot.pivot_table(values=['D'], index=['A','B'], columns=['C'], aggfunc='sum')
# Out:
#             D
# C       large small
# A   B
# bar one   4.0   5.0
#     two   7.0   6.0
# foo one   4.0   1.0
#     two   NaN   6.0

# %%
df_pivot.pivot_table(values=['D'], index=['A','B'], columns=['C'], aggfunc='sum').T
# Out:
# A        bar       foo
# B        one  two  one  two
#   C
# D large  4.0  7.0  4.0  NaN
#   small  5.0  6.0  1.0  6.0

# %%
df_pivot.groupby(['A','B','C'])['D'].aggregate([np.sum])
# Out:
#                sum
# A   B   C
# bar one large    4
#         small    5
#     two large    7
#         small    6
# foo one large    4
#         small    1
#     two small    6

# %% [markdown]
# ### Sampling

# %%
df_pivot.sample(4)
# Out:
#      A    B      C  D  E
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 3  foo  two  small  3  5
# 7  bar  two  small  6  9

# %%
df_pivot
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
weight = [0,0,0,0,0,0.01,0.49,0.2,0.3]
df_pivot.sample(n=3, weights=weight)
# Out:
#      A    B      C  D  E
# 6  bar  one  small  5  8
# 8  bar  two  large  7  9
# 5  bar  one  large  4  6

# %%
weight = [0,0,0,0,0,0.01,0.49,0.2,0.3]
df_pivot.sample(n=6, weights=weight, replace=True)
# replace=True: bootstrap sampling, sampling with replacemennt. allow duplicate samples
# Out:
#      A    B      C  D  E
# 8  bar  two  large  7  9
# 7  bar  two  small  6  9
# 7  bar  two  small  6  9
# 6  bar  one  small  5  8
# 6  bar  one  small  5  8
# 8  bar  two  large  7  9

# %%
df_pivot
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df_pivot.T
# Out:
#        0      1      2      3      4      5      6      7      8
# A    foo    foo    foo    foo    foo    bar    bar    bar    bar
# B    one    one    one    two    two    one    one    two    two
# C  small  large  large  small  small  large  small  small  large
# D      1      2      2      3      3      4      5      6      7
# E      2      4      5      5      6      6      8      9      9

# %%
df_pivot.describe()
# Out:
#               D         E
# count  9.000000  9.000000
# mean   3.666667  6.000000
# std    2.000000  2.345208
# min    1.000000  2.000000
# 25%    2.000000  5.000000
# 50%    3.000000  6.000000
# 75%    5.000000  8.000000
# max    7.000000  9.000000

# %%
df_pivot.describe().T.round(2)
# Out:
#    count  mean   std  min  25%  50%  75%  max
# D    9.0  3.67  2.00  1.0  2.0  3.0  5.0  7.0
# E    9.0  6.00  2.35  2.0  5.0  6.0  8.0  9.0

# %%
df_pivot.corr()
# Out:
#           D         E
# D  1.000000  0.959403
# E  0.959403  1.000000

# %%
df_inner.corr()
# Out:
#                id       age     price   m-point
# id       1.000000 -0.720634  0.431899  0.893685
# age     -0.720634  1.000000 -0.840497 -0.828906
# price    0.431899 -0.840497  1.000000  0.643564
# m-point  0.893685 -0.828906  0.643564  1.000000

# %% [markdown]
# ## Load Data

# %%
df_inner
# Out:
#               id  age category-size  price country       city  gender pay  \
# date
# 2013-01-05  1004   32         110-C   5433   china   shenzhen  female   Y
# 2013-01-07  1006   32         130-F   4432   china    beijing  female   Y
# 2013-01-06  1005   34         210-A   3299   china   shanghai    male   N
# 2013-01-03  1002   44         100-B   3299   china   shanghai  female   N
# 2013-01-04  1003   54         110-A   2133   china  guangzhou    male   Y
#
#             m-point group group_1 group_2 category size
# date
# 2013-01-05       40  high    high    high      110    C
# 2013-01-07       40  high    high    high      130    F
# 2013-01-06       40  high    high    high      210    A
# 2013-01-03       12  high    high    high      100    B
# 2013-01-04       20   low     low     low      110    A

# %% [markdown]
# ### Write to a csv file

# %%
df_inner.to_csv('df_inner.csv')

# %% [markdown]
# ### Write to a excel file

# %%
df_inner.to_excel('df_inner.xlsx', sheet_name='Sheet_1')
